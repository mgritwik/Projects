# %%
import pandas as pd

# %%
df=pd.read_excel("a_weight_metrics.xlsx")

# %%
df_sep=df[df['assigned_month']==202010]
cols=['company_id',
 'total_shipments',
 'wt_discrepancy_shipments_per',
 'auto_accept_shipments_per',
 'seller_accepted_shipments_per',
 'wt_dispute_shipments_per',
 'seller_favored_shipments_per',
 'no_dispute_seller_favored_shipments_per',
 'courier_favored_shipments_per',
 'wt_dispute_pending_per',
 'weight_score',
 'final_rating',
 'current_usable_balance',
 'avg_available_balance',
 'avg_used_balance',
 'avg_onhold_balance',
 'latest_available_balance',
 'latest_used_balance',
 'latest_onhold_balance']
df_wd_sep=df_sep[cols]
cols2=[ 'wt_discrepancy_shipments_per',
 'auto_accept_shipments_per',
 'seller_accepted_shipments_per',
 'wt_dispute_shipments_per',
 'seller_favored_shipments_per',
 'no_dispute_seller_favored_shipments_per',
 'courier_favored_shipments_per',
 'wt_dispute_pending_per',
 'current_usable_balance',
 'avg_available_balance',
 'avg_used_balance',
 'avg_onhold_balance',
 'latest_available_balance',
 'latest_used_balance',
 'latest_onhold_balance'    ]
df_wd_sep[cols2]=df_wd_sep[cols2].round()
df_wd_sep
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#         company_id  total_shipments  wt_discrepancy_shipments_per  \
# 87165       141118               34                          21.0
# 87166        55140             1143                          14.0
# 87167       110134              873                           7.0
# 87168       176850               47                           2.0
# 87169       222688               96                           0.0
# ...            ...              ...                           ...
# 215875       90214                1                           0.0
# ...

# %%
df_deliv=pd.read_excel("Delivery_metric_new.xlsx")

# %%
df_deliv_sep=df_deliv[df_deliv['assigned_month']==202010]
df_deliv_sep['attempted_shipment_per']=round((df_deliv_sep['total_attempted_shipments']*100)/df_deliv_sep['total_shipments'])
df_deliv_sep['ndr_escalation_raised_per']=round((df_deliv_sep['ndr_escalation_raised']*100)/df_deliv_sep['total_shipments'])
cols=['company_id',
 'total_shipments',
 'attempted_shipment_per',
 'rto_per',
 'ndr_per',
 'ndr_rto_per',
 'ndr_escalation_raised_per',
 'delivered_per',
 'first_attempt_delivered_per',
 'not_picked_shipments_per',
 'picked_after_2_days_per',
 'avg_delivered_days',
 'avg_first_delivery_days',
 'deliveries_exceeding_edd_per',
     'first_attempt_sla_breach_per',
     'delivery_sla_breach_per']
df_deliv_sep=df_deliv_sep[cols]
cols2=['attempted_shipment_per',
 'rto_per',
 'ndr_per',
 'ndr_rto_per',
 'ndr_escalation_raised_per',
 'delivered_per',
 'first_attempt_delivered_per',
 'not_picked_shipments_per',
 'picked_after_2_days_per',
 'avg_delivered_days',
 'avg_first_delivery_days',
 'deliveries_exceeding_edd_per',
      'first_attempt_sla_breach_per',
     'delivery_sla_breach_per']
df_deliv_sep[cols2]=df_deliv_sep[cols2].round()
# Out:
# <ipython-input-76-ccd30fb31b41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_deliv_sep['attempted_shipment_per']=round((df_deliv_sep['total_attempted_shipments']*100)/df_deliv_sep['total_shipments'])
# <ipython-input-76-ccd30fb31b41>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_deliv_sep['ndr_escalation_raised_per']=round((df_deliv_sep['ndr_escalation_raised']*100)/df_deliv_sep['total_shipments'])

# %%
df_nps_sep=pd.read_csv("NPS_Oct_data.csv",usecols=['company_id','score','latest_score'])
df_nps_sep['company_id']=df_nps_sep['company_id'].astype(int)
# df_nps_sep=df_nps[df_nps['month']=='September']

# %%
df_tickets_sep=pd.read_csv("Tickets_KeyFields_agg_Oct.csv")
df_tickets_sep=(df_tickets_sep[pd.to_numeric(df_tickets_sep['Company ID'], errors='coerce').notnull()])
df_tickets_sep['Company ID']=df_tickets_sep['Company ID'].astype(int)

# %%
cols=['Company ID',
 '#Tickets',
 'First response time hours',
 'Resolution time hours',
 '%Escalated',
 '%AgentResponse',
 '%ResolutioneSLA_Violated',
 '%FirstResponseSLA_Violated',
 '%HigherPriorityTickets',
 '%TypeComplaint',
 '%FCRNo']
df_tickets_sep=df_tickets_sep[cols]

# %%
# #for churned customers
# df_shipments=pd.read_excel("sr_company_summary_last_12_months_01122020.xlsx",sheet_name="shipments",usecols=['company_id','company_name','tier','month_202009','month_202010'])
# df_shipments['Sep_Oct_SD%']=''
# df_shipments['Sep_Oct_SD%']=round((df_shipments['month_202010']-df_shipments['month_202009'])*100/df_shipments['month_202009'])
# df_shipments['churned']=''
# for i in df_shipments.index:
#     if (df_shipments.at[i,'tier'] in ['GOLD','PLATINUM','TITANIUM']):
#         if(df_shipments.at[i,'Sep_Oct_SD%']<=-50):
#             df_shipments.at[i,'churned']=1
#         else:
#             df_shipments.at[i,'churned']=0
#     else:
#          if(df_shipments.at[i,'Sep_Oct_SD%']<=-70):
#             df_shipments.at[i,'churned']=1
#          else:
#             df_shipments.at[i,'churned']=0
# df_shipments.to_csv("September_Churned_sellers.csv",index=False)

# %%
#for churned customers
df_churned=pd.read_csv("October_Churned_sellers.csv")

# %%
# df_nps_oct.drop(['month'],axis=1,inplace=True)
df_nps_sep.columns=['Company ID','Avg_NPS_Score','Latest_NPS_Score']

# %%
df_deliv_sep.rename(columns = {"company_id": "Company ID"},inplace = True)
df_wd_sep.rename(columns = {"company_id": "Company ID"},inplace = True)
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_all_sep=df_tickets_sep.merge(df_nps_sep,on='Company ID',how='outer').merge(df_deliv_sep,on='Company ID',how='outer').merge(df_wd_sep,on='Company ID',how='outer')

# %%
df_churned
df_churned_sellers=df_churned[df_churned['churned']==1].company_id.tolist()
df_all_sep['churned']=0
df_churned_sellers.sort()
for i in df_all_sep.index:
    if(df_all_sep.at[i,'Company ID'] in df_churned_sellers):
        df_all_sep.at[i,'churned']=1

# %%
df_all_sep['churned']=0
df_churned_sellers.sort()
for i in df_all_sep.index:
    if(df_all_sep.at[i,'Company ID'] in df_churned_sellers):
        df_all_sep.at[i,'churned']=1

# %%
df_all_sep.to_csv('Oct_aggregated_Data.csv',index=False)
